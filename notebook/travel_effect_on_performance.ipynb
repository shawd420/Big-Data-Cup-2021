# %% [markdown]
# # Home vs Away Stats

# %%
import os
import pandas as pd
import numpy as np
import pprint

# %%
# Read in data set
path = os.path.abspath(os.path.join(os.getcwd(), '..'))
path = os.path.abspath(os.path.join(path, 'data/df_all_events.pkl'))
print(path)

df = pd.read_pickle(path)
df.head()
# Out:
# /Users/williamshaw/Projects/NHL/Big-Data-Cup-2021/data/df_all_events.pkl
#     game_date    home_team       away_team  period  clock  home_team_skaters  \
# 0  2019-09-20  Erie Otters  Sudbury Wolves       1  20:00                  5
# 1  2019-09-20  Erie Otters  Sudbury Wolves       1  19:58                  5
# 2  2019-09-20  Erie Otters  Sudbury Wolves       1  19:53                  5
# 3  2019-09-20  Erie Otters  Sudbury Wolves       1  19:52                  5
# 4  2019-09-20  Erie Otters  Sudbury Wolves       1  19:51                  5
#
#    away_team_skaters  home_team_goals  away_team_goals            team  ...  \
# 0                  5                0                0  Sudbury Wolves  ...
# 1                  5                0                0  Sudbury Wolves  ...
# 2                  5                0                0  Sudbury Wolves  ...
# 3                  5                0                0     Erie Otters  ...
# 4                  5                0                0     Erie Otters  ...
#
#              event x_coord_1  y_coord_1  detail_1 detail_2 detail_3 detail_4  \
# 0      Faceoff Win       100         43  Forehand      NaN      NaN      NaN
# 1    Puck Recovery        67         77       NaN      NaN      NaN      NaN
# 2  Incomplete Play        45         49    Direct      NaN      NaN      NaN
# 3    Puck Recovery        89         36       NaN      NaN      NaN      NaN
# 4  Incomplete Play        82         49    Direct      NaN      NaN      NaN
#
#           player_2 x_coord_2  y_coord_2
# 0  Connor Lockhart       NaN        NaN
# 1              NaN       NaN        NaN
# 2     Blake Murray      74.0       35.0
# 3              NaN       NaN        NaN
# 4  Connor Lockhart      94.0       46.0
#
# [5 rows x 21 columns]

# %%
# show different types of event details
df.groupby('event')['detail_1'].value_counts()
# Out:
# event            detail_1
# Dump In/Out      Lost                          4143
#                  Retained                       745
# Faceoff Win      Backhand                      2179
#                  Forehand                       245
#                  Feet                            17
# Goal             Snapshot                       148
#                  Wristshot                      115
#                  Deflection                      17
#                  Slapshot                         8
#                  Wrap Around                      5
# Incomplete Play  Direct                        5692
#                  Indirect                      3198
# Penalty Taken    Roughing                        50
#                  Slashing                        44
#                  Tripping                        44
#                  Hooking                         35
#                  Fighting                        32
#                  High-sticking                   32
#                  Cross-checking                  31
#                  Unsportsmanlike conduct         27
#                  Holding                         24
#                  Interference                    18
#                  Instigator                      15
#                  Illegal Check to the Head       13
#                  Delay of game                   12
#                  Too many men on the ice          8
#                  Misconduct                       7
#                  Goalkeeper interference          5
#                  Holding the stick                5
#                  Checking from behind             4
#                  Diving                           4
#                  Boarding                         3
#                  Kneeing                          3
#                  Elbowing                         1
#                  Illegal equipment                1
#                  Spearing                         1
# Play             Direct                       16706
#                  Indirect                      7072
# Shot             Wristshot                     2481
#                  Snapshot                      1509
#                  Slapshot                       431
#                  Deflection                     246
#                  Fan                            184
#                  Wrap Around                     36
# Zone Entry       Carried                       3632
#                  Dumped                        2173
#                  Played                         557
# Name: detail_1, dtype: int64

# %%
# convert dataframe to iterable python dict
events = df.to_dict(orient='records')

# %%
# count the number of events per player per date --- this will track the number of games played per player
home_gp = {}
away_gp = {}
cur_date = ''
num_home_games = 0
num_away_games = 0

date_change = 0
for e in events:
    if e['game_date'] != cur_date:
        date_change += 1
        cur_date = e['game_date']
        if e['home_team'] == 'Erie Otters': 
            print('date changed to ' + cur_date + ' | Home game')
            num_home_games += 1
        else: 
            print('date changed to ' + cur_date + ' |              Away game')
            num_away_games += 1
        
    # we only want to track Erie players
    if e['team'] != 'Erie Otters':
        continue

    # figure out if this game is home or away
    home_or_away_gp = home_gp
    if e['home_team'] != 'Erie Otters':
        home_or_away_gp = away_gp

    # if player has appeared in any games yet, add him to the dict
    player_name = e['player_1']
    if player_name not in home_or_away_gp:
        home_or_away_gp[player_name] = {}
            
    # if player has not had any events for this game yet, add this game
    if cur_date not in home_or_away_gp[player_name]:
        home_or_away_gp[player_name][cur_date] = 1
    else: home_or_away_gp[player_name][cur_date] += 1
        
print('\ntotal games: ' + str(date_change))
print('total home games: ' + str(num_home_games))
print('total away games: ' + str(num_away_games))
# Out:
# date changed to 2019-09-20 | Home game
# date changed to 2019-09-21 |              Away game
# date changed to 2019-09-26 |              Away game
# date changed to 2019-10-04 | Home game
# date changed to 2019-10-11 | Home game
# date changed to 2019-10-12 | Home game
# date changed to 2019-10-17 |              Away game
# date changed to 2019-10-18 |              Away game
# date changed to 2019-10-19 | Home game
# date changed to 2019-10-23 | Home game
# date changed to 2019-10-26 | Home game
# date changed to 2019-11-09 |              Away game
# date changed to 2019-11-15 | Home game
# date changed to 2019-11-17 |              Away game
# date changed to 2019-11-21 |              Away game
# date changed to 2019-11-22 |              Away game
# date changed to 2019-12-08 | Home game
# date changed to 2019-12-13 |              Away game
# date changed to 2019-12-15 |              Away game
# date changed to 2019-12-29 |              Away game
# date changed to 2019-12-31 | Home game
# date changed to 2020-01-03 |              Away game
# date changed to 2020-01-05 |              Away game
# date changed to 2020-01-11 | Home game
# date changed to 2020-01-12 | Home game
# date changed to 2020-01-17 |              Away game
# date changed to 2020-01-18 |              Away game
# date changed to 2020-01-31 |              Away game
# date changed to 2020-02-05 |              Away game
# date changed to 2020-02-07 | Home game
# date changed to 2020-02-08 | Home game
# date changed to 2020-02-12 | Home game
# date changed to 2020-02-17 |              Away game
# date changed to 2020-02-21 |              Away game
# date changed to 2020-02-23 |              Away game
# date changed to 2020-02-29 | Home game
# date changed to 2020-03-01 | Home game
# date changed to 2020-03-04 | Home game
# date changed to 2020-03-07 |              Away game
# date changed to 2020-03-08 | Home game
#
# total games: 40
# total home games: 19
# total away games: 21

# %%
# print('Home games played for each player:')
# for key, value in home_gp.items():
#     print(str(key) + ' : ' + str(len(value)))
    
# print('\nAway games played for each player:')
# for key, value in away_gp.items():
#     print(str(key) + ' : ' + str(len(value)))

# %%
# count faceoff losses
erie_home_faceoff_losses = {}
erie_away_faceoff_losses = {}

for e in events:
    if e['event'] == 'Faceoff Win' and e['team'] != 'Erie Otters':
        
        # find out if home or away during faceoff loss
        home_or_away_dict = erie_home_faceoff_losses
        if e['home_team'] != 'Erie Otters':
            home_or_away_dict = erie_away_faceoff_losses
        
        # increment player's faceoff losses total for home/away games
        player_name = e['player_2']
        if player_name not in home_or_away_dict:
            home_or_away_dict[player_name] = 0
        home_or_away_dict[player_name] += 1

# %%
pprint.pprint(erie_home_faceoff_losses)
print()
pprint.pprint(erie_away_faceoff_losses)
# Out:
# {'Alex Gritz': 3,
#  'Austen Swankler': 86,
#  'Brendan Hoffmann': 126,
#  'Brendan Sellan': 1,
#  'Chad Yetman': 184,
#  'Connor Lockhart': 70,
#  'Danial Singer': 3,
#  "Daniel D'Amato": 6,
#  'Elias Cohen': 31,
#  'Emmett Sproule': 4,
#  'Hayden Fowler': 59,
#  'Jamie Drysdale': 1,
#  'Kyen Sopa': 2,
#  'Matthew MacDougall': 1,
#  'Maxim Golod': 2,
#  'Noah Sedore': 13}
#
# {'Alex Gritz': 8,
#  'Austen Swankler': 79,
#  'Brendan Hoffmann': 165,
#  'Brendan Sellan': 5,
#  'Brett Bressette': 6,
#  'Chad Yetman': 197,
#  'Connor Lockhart': 45,
#  'Danial Singer': 3,
#  "Daniel D'Amato": 22,
#  'Elias Cohen': 61,
#  'Emmett Sproule': 7,
#  'Hayden Fowler': 102,
#  'Jamie Drysdale': 1,
#  'Kyen Sopa': 6,
#  'Matthew MacDougall': 3,
#  'Maxim Golod': 11,
#  'Noah Sedore': 25}

# %%
# count home and away stats of Erie Otters players in separate dicts
home_stats_erie = {}
away_stats_erie = {}
new_player_dict = {
    'dump_retained': 0,       # successful dump in attempt
    'dump_lost': 0,           # unsuccessful dump in attempt
    'faceoff_win': 0,         # face off won
    'faceoff_lost': 0,        # face off lost
    'goals': 0,               # goals
    'shots': 0,               # total shots
    'shots_on_net': 0,        # number of shots on goal
    'shots_missed': 0,        # number of attempted shots that miss net
    'shots_blocked': 0,       # number of attempted shots that are blocked
    'zone_entry_carried': 0,  # puck carried into offensive zone
    'zone_entry_dumped': 0,   # puck dumped into offesnive zone
    'zone_entry_played': 0,   # puck played into offesnive zone via pass
    'penalty_taken': 0,       # number of penalties taken
    'play_indirect': 0,       # successful indirect passes (i.e. pass rimmed of boards)
    'play_direct': 0,         # successful direct passes (i.e. tape to tape pass)
    'inc_play_indirect': 0,   # unsuccessful indirect passes (i.e. pass rimmed of boards)
    'inc_play_direct': 0,     # unsuccessful direct passes (i.e. tape to tape pass)
    'games_played': 0
}

for e in events:
    if e['team'] == 'Erie Otters':
        # found Erie player! now figure out if this event belongs to the home or away dataset
        home_or_away_dict = home_stats_erie
        if e['home_team'] != 'Erie Otters':
            home_or_away_dict = away_stats_erie
        
        # if this player has not been seen yet, add them to the dict so we can track their stats
        player_name = e['player_1']
        if player_name not in home_or_away_dict:
            home_or_away_dict[player_name] = new_player_dict.copy()  # add player to dict
        
        # identify event that happend
        event_name = ''
        if e['event'] == 'Dump In/Out' and e['detail_1'] == 'Lost': event_name = 'dump_lost'
        elif e['event'] == 'Dump In/Out' and e['detail_1'] == 'Retained': event_name = 'dump_retained'
        elif e['event'] == 'Faceoff Win': event_name = 'faceoff_win'
        elif e['event'] == 'Goal': event_name = 'goals'   
        elif e['event'] == 'Shot': 
            home_or_away_dict[player_name]['shots'] += 1
            if e['detail_2'] == 'On Net': event_name = 'shots_on_net'
            elif e['detail_2'] == 'Missed': event_name = 'shots_missed'
            elif e['detail_2'] == 'Blocked': event_name = 'shots_blocked'
        elif e['event'] == 'Zone Entry' and e['detail_1'] == 'Carried': event_name = 'zone_entry_carried'
        elif e['event'] == 'Zone Entry' and e['detail_1'] == 'Dumped': event_name = 'zone_entry_dumped'
        elif e['event'] == 'Zone Entry' and e['detail_1'] == 'Played': event_name = 'zone_entry_played'
        elif e['event'] == 'Penalty Taken': event_name = 'penalty_taken'
        elif e['event'] == 'Play' and e['detail_1'] == 'Indirect': event_name = 'play_indirect'
        elif e['event'] == 'Play' and e['detail_1'] == 'Direct': event_name = 'play_direct'
        elif e['event'] == 'Incomplete Play' and e['detail_1'] == 'Indirect': event_name = 'inc_play_indirect'
        elif e['event'] == 'Incomplete Play' and e['detail_1'] == 'Direct': event_name = 'inc_play_direct'
            
        
        # if identified an event we care about, increment that stat
        if len(event_name) > 0:
            home_or_away_dict[player_name][event_name] += 1
        
# append  games played and faceoffs lost to correct dataframes
for player_name in home_stats_erie:
    # home stats
    if player_name in home_gp:
        home_stats_erie[player_name]['games_played'] = len(home_gp[player_name])
    if player_name in erie_home_faceoff_losses:
        home_stats_erie[player_name]['faceoff_lost'] = erie_home_faceoff_losses[player_name]
    
    # away stats
    if player_name in away_gp:
        away_stats_erie[player_name]['games_played'] = len(away_gp[player_name])
    if player_name in erie_away_faceoff_losses:
        away_stats_erie[player_name]['faceoff_lost'] = erie_away_faceoff_losses[player_name]

# %%
for e in events:
    if e['player_1'] == 'Jamie Drysdale' and e['event'] == 'Goal':
        pprint.pprint(e['home_team'])
# Out:
# 'Hamilton Bulldogs'
# 'Niagara Ice Dogs'
# 'Niagara Ice Dogs'
# 'Guelph Storm'
# 'Erie Otters'
# 'Kitchener Rangers'

# %%
# df_home = pd.DataFrame(home_stats_erie).transpose()
# df_away = pd.DataFrame(away_stats_erie).transpose()

# df_home[df_home['games_played'] >= 5]
df_home = pd.DataFrame.from_dict(home_stats_erie, orient='index')
df_home_per_game = df_home.div(df_home['games_played'], axis=0)

df_away = pd.DataFrame.from_dict(away_stats_erie, orient='index')
df_away_per_game = df_away.div(df_away['games_played'], axis=0)

df_diff = df_home_per_game - df_away_per_game
df_diff['games_played'] = df_home['games_played'] + df_away['games_played']
df_diff['games_played_home'] = df_home['games_played']
df_diff['games_played_away'] = df_away['games_played']
# display(df_home)
# display(df_away)

# %%
df_home
# Out:
#                     dump_retained  dump_lost  faceoff_win  faceoff_lost  \
# Hayden Fowler                  13         42           70            59
# Jamie Drysdale                 13         48            0             1
# Kurtis Henry                   14         78            0             0
# Brendan Sellan                 18         86            1             1
# Connor Lockhart                11         41           50            70
# Danial Singer                   2         21            1             3
# Jacob Golden                    8         57            0             0
# Austen Swankler                12         59           84            86
# Emmett Sproule                  9         59            3             4
# Jack Duff                      12         79            0             0
# Chad Yetman                     7         43          195           184
# Maxim Golod                    14         56            1             2
# Alex Gritz                      0          0            4             3
# Elias Cohen                     0         16           35            31
# Brendan Kischnick               3         13            0             0
# Brendan Hoffmann               11         45           93           126
# Luke Beamish                    3         19            0             0
# Daniel D'Amato                 13         49           11             6
# Daniel Murphy                   0          2            0             0
# Cameron Morton                  8         40            0             0
# Noah Sedore                     4         27           12            13
# Aidan Campbell                  0          1            0             0
# Matthew MacDougall              5          9            0             1
# Christian Kyrou                 0          4            0             0
# Drew Hunter                     4         27            0             0
# Brett Bressette                 1          2            0             0
# Kyen Sopa                       3         33            2             2
#
#                     goals  shots  shots_on_net  shots_missed  shots_blocked  \
# Hayden Fowler           7     63            30            20             13
# Jamie Drysdale          1    107            43            30             34
# Kurtis Henry            1     75            26            25             24
# Brendan Sellan          5     72            37            21             14
# Connor Lockhart         2     57            31            19              7
# Danial Singer           1     46            17            12             17
# Jacob Golden            1     66            21            19             26
# Austen Swankler         6     91            49            25             17
# Emmett Sproule          3     70            33            18             19
# Jack Duff               2     78            28            24             26
# Chad Yetman            14    118            61            34             23
# Maxim Golod             7    118            66            34             18
# Alex Gritz              0      2             1             1              0
# Elias Cohen             1     27            16            10              1
# Brendan Kischnick       0     22             6             6             10
# Brendan Hoffmann        5     73            35            19             19
# Luke Beamish            0     15             5             8              2
# Daniel D'Amato          5     52            24            21              7
# Daniel Murphy           0      0             0             0              0
# Cameron Morton          0     45            18            14             13
# Noah Sedore             1     15             7             3              5
# Aidan Campbell          0      0             0             0              0
# Matthew MacDougall      0     17            10             1              6
# Christian Kyrou         0      0             0             0              0
# Drew Hunter             1     52            25            15             12
# Brett Bressette         0      1             1             0              0
# Kyen Sopa               3     42            24            11              7
#
#                     zone_entry_carried  zone_entry_dumped  zone_entry_played  \
# Hayden Fowler                       69                 23                  9
# Jamie Drysdale                      36                 22                 12
# Kurtis Henry                        13                 26                  3
# Brendan Sellan                      54                 51                 11
# Connor Lockhart                     40                 33                  5
# Danial Singer                       25                 13                  6
# Jacob Golden                        37                 28                  1
# Austen Swankler                     93                 45                 11
# Emmett Sproule                      76                 47                  8
# Jack Duff                           14                 27                  7
# Chad Yetman                         99                 28                 11
# Maxim Golod                        136                 46                 15
# Alex Gritz                           2                  0                  0
# Elias Cohen                         22                  9                  6
# Brendan Kischnick                    3                  7                  2
# Brendan Hoffmann                    52                 26                  8
# Luke Beamish                         8                  9                  0
# Daniel D'Amato                      57                 36                  6
# Daniel Murphy                        0                  0                  0
# Cameron Morton                       1                 21                  1
# Noah Sedore                         21                 20                  2
# Aidan Campbell                       0                  0                  0
# Matthew MacDougall                  25                 10                  5
# Christian Kyrou                      1                  1                  0
# Drew Hunter                         13                 16                  4
# Brett Bressette                      1                  3                  0
# Kyen Sopa                           39                 19                  2
#
#                     penalty_taken  play_indirect  play_direct  \
# Hayden Fowler                   3             78          212
# Jamie Drysdale                  2            146          438
# Kurtis Henry                    4            150          248
# Brendan Sellan                  4             94          155
# Connor Lockhart                 4             75          157
# Danial Singer                   2             21           66
# Jacob Golden                    0            101          324
# Austen Swankler                 8            102          256
# Emmett Sproule                  2             68          202
# Jack Duff                      12            113          262
# Chad Yetman                     2            130          287
# Maxim Golod                     8            131          415
# Alex Gritz                      0              8            4
# Elias Cohen                     2             50          115
# Brendan Kischnick               4             28           53
# Brendan Hoffmann                3             62           95
# Luke Beamish                    0             50          107
# Daniel D'Amato                  3             89          144
# Daniel Murphy                   0             88           32
# Cameron Morton                  8             69          119
# Noah Sedore                     3             24           69
# Aidan Campbell                  0             71           16
# Matthew MacDougall              1             30           60
# Christian Kyrou                 0              3           10
# Drew Hunter                     2             81          213
# Brett Bressette                 0              1            3
# Kyen Sopa                       7             41          112
#
#                     inc_play_indirect  inc_play_direct  games_played
# Hayden Fowler                      26              140            17
# Jamie Drysdale                     54               91            15
# Kurtis Henry                       65               73            19
# Brendan Sellan                     49               62            19
# Connor Lockhart                    21               62            18
# Danial Singer                       6               22            10
# Jacob Golden                       55               72            17
# Austen Swankler                    45              111            18
# Emmett Sproule                     30               94            19
# Jack Duff                          61               72            19
# Chad Yetman                        32               80            19
# Maxim Golod                        34              147            19
# Alex Gritz                          3                3             1
# Elias Cohen                        22               52            16
# Brendan Kischnick                  20               14             7
# Brendan Hoffmann                   28               51            19
# Luke Beamish                       22               15             6
# Daniel D'Amato                     35               61            19
# Daniel Murphy                      18                2            13
# Cameron Morton                     39               41            17
# Noah Sedore                        12               33            14
# Aidan Campbell                     10                6             8
# Matthew MacDougall                  8               26             9
# Christian Kyrou                     1                5             3
# Drew Hunter                        46               51            12
# Brett Bressette                     1                2             1
# Kyen Sopa                          20               36             9

# %%
df_diff[df_diff['games_played'] >= 8].mean(axis=0)
# Out:
# dump_retained         -0.012076
# dump_lost             -0.085745
# faceoff_win            0.134902
# faceoff_lost          -0.255175
# goals                 -0.042511
# shots                  0.318385
# shots_on_net           0.146620
# shots_missed           0.131578
# shots_blocked          0.040187
# zone_entry_carried     0.110186
# zone_entry_dumped      0.089019
# zone_entry_played      0.075263
# penalty_taken         -0.052666
# play_indirect          0.389694
# play_direct            0.310010
# inc_play_indirect      0.053071
# inc_play_direct        0.214446
# games_played          30.040000
# games_played_home     14.440000
# games_played_away     15.600000
# dtype: float64
